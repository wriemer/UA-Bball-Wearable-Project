# %%
# %pip install ultralytics==8.0.196
# %pip install roboflow
# Out:
# Requirement already satisfied: ultralytics==8.0.196 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (8.0.196)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from ultralytics==8.0.196) (3.9.2)
# Requirement already satisfied: numpy>=1.22.2 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from ultralytics==8.0.196) (1.26.4)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from ultralytics==8.0.196) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from ultralytics==8.0.196) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from ultralytics==8.0.196) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from ultralytics==8.0.196) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from ultralytics==8.0.196) (1.14.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from ultralytics==8.0.196) (2.5.0+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from ultralytics==8.0.196) (0.20.0+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from ultralytics==8.0.196) (4.66.4)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from ultralytics==8.0.196) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from ultralytics==8.0.196) (0.13.2)
# Requirement already satisfied: psutil in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from ultralytics==8.0.196) (6.0.0)
# Requirement already satisfied: py-cpuinfo in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from ultralytics==8.0.196) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from ultralytics==8.0.196) (0.1.1.post2209072238)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.1.4->ultralytics==8.0.196) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.1.4->ultralytics==8.0.196) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.23.0->ultralytics==8.0.196) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.23.0->ultralytics==8.0.196) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.23.0->ultralytics==8.0.196) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.23.0->ultralytics==8.0.196) (2024.6.2)
# Requirement already satisfied: filelock in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics==8.0.196) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics==8.0.196) (4.12.2)
# Requirement already satisfied: networkx in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics==8.0.196) (3.3)
# Requirement already satisfied: jinja2 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics==8.0.196) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics==8.0.196) (2024.9.0)
# Requirement already satisfied: setuptools in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics==8.0.196) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics==8.0.196) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics==8.0.196) (1.3.0)
# Requirement already satisfied: colorama in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.64.0->ultralytics==8.0.196) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics==8.0.196) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics==8.0.196) (2.1.5)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ltralytics (c:\Users\ajkac\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ltralytics (c:\Users\ajkac\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ltralytics (c:\Users\ajkac\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# Requirement already satisfied: roboflow in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (1.1.45)
# Requirement already satisfied: certifi in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (2024.6.2)
# Requirement already satisfied: idna==3.7 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (1.4.7)
# Requirement already satisfied: matplotlib in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (3.9.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (1.26.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (10.3.0)
# Requirement already satisfied: python-dateutil in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (2.2.2)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (4.66.4)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests-toolbelt in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: colorama in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->roboflow) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->roboflow) (4.53.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->roboflow) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->roboflow) (3.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ajkac\appdata\local\programs\python\python312\lib\site-packages (from requests->roboflow) (3.3.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ltralytics (c:\Users\ajkac\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ltralytics (c:\Users\ajkac\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ltralytics (c:\Users\ajkac\AppData\Local\Programs\Python\Python312\Lib\site-packages)

# %% [markdown]
# ### Download training dataset from roboflow
#
# FYI this was run in Google Colab (to avoid running this on local computer) w/ the resulting model then downloaded and added to this project.

# %%
# training dataset: https://universe.roboflow.com/test-datset/player_detect-0spfb

from roboflow import Roboflow

rf = Roboflow(api_key="vmmLeTXBptgOqEweeYta")
project = rf.workspace("workspace-mvcuz").project("basketball-courtside-detection-2")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 8
#       6 project = rf.workspace("workspace-mvcuz").project("basketball-courtside-detection-2")
#       7 version = project.version(1)
# ----> 8 dataset = version.download("yolov8")
#
# File c:\Users\ajkac\AppData\Local\Programs\Python\Python312\Lib\site-packages\roboflow\core\version.py:207, in Version.download(self, model_format, location, overwrite)
#     186 def download(self, model_format=None, location=None, overwrite: bool = False):
#     187     """
#     188     Download and extract a ZIP of a version's dataset in a given format
#     189
#    (...)
#     204         HTTPError: If the Network/Roboflow API fails and does not return JSON
#     205     """  # noqa: E501 // docs
# --> 207     self.__wait_if_generating()
#     209     if model_format == "yolov8":
#     210         # if ultralytics is installed, we will assume users will want to use yolov8 and we check for the supported version  # noqa: E501 // docs
#     211         try:
#
# File c:\Users\ajkac\AppData\Local\Programs\Python\Python312\Lib\site-packages\roboflow\core\version.py:171, in Version.__wait_if_generating(self, recurse)
#     168 def __wait_if_generating(self, recurse=False):
#     169     # checks if a given version is still in the progress of generating
# --> 171     still_generating, progress = self.__check_if_generating()
#     173     if still_generating:
#     174         progress_message = "Generating version still in progress. Progress: " + str(round(progress * 100, 2)) + "%"
#
# File c:\Users\ajkac\AppData\Local\Programs\Python\Python312\Lib\site-packages\roboflow\core\version.py:159, in Version.__check_if_generating(self)
#     155 def __check_if_generating(self):
#     156     # check Roboflow API to see if this version is still generating
#     158     url = f"{API_URL}/{self.workspace}/{self.project}/{self.version}?nocache=true"
# --> 159     response = requests.get(url, params={"api_key": self.__api_key})
#     160     response.raise_for_status()
#     161     if response.json()["version"]["progress"] is None:
#
# File c:\Users\ajkac\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\ajkac\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\ajkac\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\ajkac\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\ajkac\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\ajkac\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File c:\Users\ajkac\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\ajkac\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\ajkac\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File c:\Users\ajkac\AppData\Local\Programs\Python\Python312\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File c:\Users\ajkac\AppData\Local\Programs\Python\Python312\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File c:\Users\ajkac\AppData\Local\Programs\Python\Python312\Lib\socket.py:708, in SocketIO.readinto(self, b)
#     706 while True:
#     707     try:
# --> 708         return self._sock.recv_into(b)
#     709     except timeout:
#     710         self._timeout_occurred = True
#
# File c:\Users\ajkac\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\ajkac\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
dataset.location
# Out:
# 'c:\\Users\\ajkac\\Documents\\CS495\\UA-Bball-Wearable-Project\\CV\\training\\Basketball-Courtside-Detection-2-1'

# %%
# move folder location of training data

import shutil

shutil.move('Basketball-Courtside-Detection-1/train', 'Basketball-Courtside-Detection-1/Basketball-Courtside-Detection-1/train')

shutil.move('Basketball-Courtside-Detection-1/test', 'Basketball-Courtside-Detection-1/Basketball-Courtside-Detection-1/test')

shutil.move('Basketball-Courtside-Detection-1/valid', 'Basketball-Courtside-Detection-1/Basketball-Courtside-Detection-1/valid')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\ajkac\AppData\Local\Programs\Python\Python312\Lib\shutil.py:847, in move(src, dst, copy_function)
#     846 try:
# --> 847     os.rename(src, real_dst)
#     848 except OSError:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'Basketball-Courtside-Detection-1/train' -> 'Basketball-Courtside-Detection-1/Basketball-Courtside-Detection-1/train\\train'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 5
#       1 # move folder location of training data
#       3 import shutil
# ----> 5 shutil.move('Basketball-Courtside-Detection-1/train', 'Basketball-Courtside-Detection-1/Basketball-Courtside-Detection-1/train')
#       7 shutil.move('Basketball-Courtside-Detection-1/test', 'Basketball-Courtside-Detection-1/Basketball-Courtside-Detection-1/test')
#       9 shutil.move('Basketball-Courtside-Detection-1/valid', 'Basketball-Courtside-Detection-1/Basketball-Courtside-Detection-1/valid')
#
# File c:\Users\ajkac\AppData\Local\Programs\Python\Python312\Lib\shutil.py:867, in move(src, dst, copy_function)
#     865         rmtree(src)
#     866     else:
# --> 867         copy_function(src, real_dst)
#     868         os.unlink(src)
#     869 return real_dst
#
# File c:\Users\ajkac\AppData\Local\Programs\Python\Python312\Lib\shutil.py:460, in copy2(src, dst, follow_symlinks)
#     458     flags |= _winapi.COPY_FILE_COPY_SYMLINK
#     459 try:
# --> 460     _winapi.CopyFile2(src_, dst_, flags)
#     461     return dst
#     462 except OSError as exc:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified

# %% [markdown]
# ### Train on dataset

# %%
# Chose yolov8n (nano) for fastes model, may be less accurate than other sizes
from ultralytics import YOLO
import torch

device = 'cuda'
print("Available device:", torch.cuda.get_device_name(0))

model = YOLO('yolov8s.pt').to(device)
data_path = f'{dataset.location}/data.yaml'
model.train(data=data_path, epochs=225, imgsz=640, workers=2)

#!yolo task=detect mode=train model=yolov8l.pt data={dataset.location}/data.yaml epochs=1 imgsz=640
# Out:
# Available device: NVIDIA GeForce RTX 3070 Laptop GPU
# New https://pypi.org/project/ultralytics/8.3.21 available  Update with 'pip install -U ultralytics'
# engine\trainer: task=detect, mode=train, model=yolov8n.pt, data=c:\Users\ajkac\Documents\CS495\UA-Bball-Wearable-Project\CV\training\Basketball-Courtside-Detection-2-1/data.yaml, epochs=225, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=cuda:0, workers=2, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs\detect\train38
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752092  ultralytics.nn.modules.head.Detect           [4, [64, 128, 256]]
# Model summary: 225 layers, 3011628 parameters, 3011612 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed
# train: Scanning C:\Users\ajkac\Documents\CS495\UA-Bball-Wearable-Project\CV\training\Basketball-Courtside-Detection-2-1\train\labels.cache... 1641 images, 9 backgrounds, 0 corrupt: 100%|██████████| 1641/1641 [00:00<?, ?it/s]
# WARNING  Box and segment counts should be equal, but got len(segments) = 15, len(boxes) = 12873. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# val: Scanning C:\Users\ajkac\Documents\CS495\UA-Bball-Wearable-Project\CV\training\Basketball-Courtside-Detection-2-1\valid\labels.cache... 169 images, 1 backgrounds, 0 corrupt: 100%|██████████| 169/169 [00:00<?, ?it/s]
# WARNING  Box and segment counts should be equal, but got len(segments) = 15, len(boxes) = 1397. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to runs\detect\train38\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs\detect\train38
# Starting training for 225 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/225      2.36G      1.519      2.076      1.322        107        640: 100%|██████████| 103/103 [00:13<00:00,  7.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.70it/s]
#                    all        169       1397      0.705      0.253      0.354      0.219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/225      2.26G      1.407      1.462      1.245         94        640: 100%|██████████| 103/103 [00:12<00:00,  8.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.34it/s]
#                    all        169       1397       0.48      0.448       0.43      0.243
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/225      2.25G      1.395      1.371      1.245        118        640: 100%|██████████| 103/103 [00:12<00:00,  8.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.72it/s]
#                    all        169       1397      0.455      0.436      0.409      0.243
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/225      2.26G      1.404      1.327      1.255         96        640: 100%|██████████| 103/103 [00:12<00:00,  8.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.84it/s]
#                    all        169       1397      0.532      0.572      0.534      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/225      2.23G      1.372      1.258      1.235        128        640: 100%|██████████| 103/103 [00:12<00:00,  8.49it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.83it/s]
#                    all        169       1397       0.59      0.505      0.535      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/225      2.26G      1.345      1.213      1.216        168        640: 100%|██████████| 103/103 [00:12<00:00,  8.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.80it/s]
#                    all        169       1397      0.581      0.512      0.548      0.317
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/225      2.25G      1.326      1.164      1.213         88        640: 100%|██████████| 103/103 [00:12<00:00,  8.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.80it/s]
#                    all        169       1397      0.706      0.548      0.621      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/225      2.25G        1.3      1.131      1.195        125        640: 100%|██████████| 103/103 [00:12<00:00,  8.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.84it/s]
#                    all        169       1397      0.709      0.569      0.634      0.382
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/225      2.25G      1.286      1.104      1.189        123        640: 100%|██████████| 103/103 [00:12<00:00,  8.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.07it/s]
#                    all        169       1397      0.696      0.563      0.631      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/225      2.25G      1.283      1.068      1.185        133        640: 100%|██████████| 103/103 [00:12<00:00,  8.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.97it/s]
#                    all        169       1397      0.657      0.577      0.626      0.367
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/225      2.26G      1.272      1.056      1.179        141        640: 100%|██████████| 103/103 [00:12<00:00,  8.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.73it/s]
#                    all        169       1397      0.714      0.587       0.66      0.392
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/225      2.25G      1.243      1.031      1.175         80        640: 100%|██████████| 103/103 [00:12<00:00,  8.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.04it/s]
#                    all        169       1397      0.715      0.581      0.651      0.393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/225      2.35G      1.248      1.024      1.171        135        640: 100%|██████████| 103/103 [00:12<00:00,  8.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.08it/s]
#                    all        169       1397      0.649      0.677      0.669      0.394
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/225      2.26G      1.239      1.023      1.163         73        640: 100%|██████████| 103/103 [00:12<00:00,  8.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.86it/s]
#                    all        169       1397      0.744      0.586      0.677      0.413
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/225      2.26G      1.208     0.9746      1.146        113        640: 100%|██████████| 103/103 [00:12<00:00,  8.37it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.05it/s]
#                    all        169       1397      0.682      0.652       0.68      0.402
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/225      2.25G      1.212      0.976       1.15        123        640: 100%|██████████| 103/103 [00:12<00:00,  8.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.99it/s]
#                    all        169       1397      0.731      0.611      0.678      0.414
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/225      2.26G      1.194     0.9528      1.139         92        640: 100%|██████████| 103/103 [00:12<00:00,  8.38it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.98it/s]
#                    all        169       1397      0.751      0.634      0.693      0.416
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/225      2.36G      1.208     0.9656      1.145        108        640: 100%|██████████| 103/103 [00:12<00:00,  8.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.98it/s]
#                    all        169       1397      0.677      0.659      0.688       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/225      2.27G      1.174     0.9323      1.132        121        640: 100%|██████████| 103/103 [00:12<00:00,  8.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.77it/s]
#                    all        169       1397      0.761      0.601      0.679      0.405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/225      2.24G       1.17     0.9092      1.136         74        640: 100%|██████████| 103/103 [00:12<00:00,  8.38it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.01it/s]
#                    all        169       1397      0.729      0.667      0.702       0.42
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/225      2.27G      1.154     0.9075      1.127        128        640: 100%|██████████| 103/103 [00:12<00:00,  8.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.91it/s]
#                    all        169       1397      0.785      0.601      0.699      0.428
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/225      2.24G       1.16     0.9043      1.122        117        640: 100%|██████████| 103/103 [00:12<00:00,  8.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.04it/s]
#                    all        169       1397      0.753      0.644      0.704      0.431
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/225      2.45G      1.146     0.8939      1.116         83        640: 100%|██████████| 103/103 [00:12<00:00,  8.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.06it/s]
#                    all        169       1397      0.697      0.649      0.678      0.413
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/225      2.24G      1.126      0.876      1.107        149        640: 100%|██████████| 103/103 [00:12<00:00,  8.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.00it/s]
#                    all        169       1397      0.764      0.614      0.695       0.42
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/225      2.33G      1.131     0.8668      1.107        110        640: 100%|██████████| 103/103 [00:12<00:00,  8.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.20it/s]
#                    all        169       1397      0.684      0.664      0.691      0.421
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/225      2.26G      1.134     0.8709      1.113        142        640: 100%|██████████| 103/103 [00:12<00:00,  8.30it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.93it/s]
#                    all        169       1397      0.757      0.614      0.699      0.435
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/225      2.36G      1.134     0.8639       1.11        109        640: 100%|██████████| 103/103 [00:12<00:00,  8.26it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.86it/s]
#                    all        169       1397      0.716      0.617      0.688      0.419
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/225      2.36G      1.127     0.8597      1.104         73        640: 100%|██████████| 103/103 [00:12<00:00,  8.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.00it/s]
#                    all        169       1397      0.754      0.646      0.699       0.43
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/225      2.36G      1.106     0.8419      1.102        115        640: 100%|██████████| 103/103 [00:12<00:00,  8.28it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.16it/s]
#                    all        169       1397      0.705      0.685      0.722      0.447
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/225      2.34G      1.111     0.8309      1.095         74        640: 100%|██████████| 103/103 [00:12<00:00,  8.26it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.09it/s]
#                    all        169       1397      0.702      0.656      0.698      0.427
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/225      2.26G      1.104     0.8414      1.094        103        640: 100%|██████████| 103/103 [00:12<00:00,  8.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.08it/s]
#                    all        169       1397      0.731      0.637      0.683      0.427
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/225      2.24G      1.089     0.8183       1.09        156        640: 100%|██████████| 103/103 [00:12<00:00,  8.30it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.94it/s]
#                    all        169       1397      0.759      0.649      0.716       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/225      2.36G      1.091     0.8118      1.091        112        640: 100%|██████████| 103/103 [00:12<00:00,  8.30it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.16it/s]
#                    all        169       1397      0.688      0.657      0.687      0.427
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/225      2.34G      1.082      0.801      1.087        152        640: 100%|██████████| 103/103 [00:12<00:00,  8.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.04it/s]
#                    all        169       1397      0.793      0.637      0.729      0.449
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/225      2.35G      1.083     0.8021      1.082        130        640: 100%|██████████| 103/103 [00:12<00:00,  8.14it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.87it/s]
#                    all        169       1397      0.723      0.633      0.686      0.432
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/225      2.26G      1.064     0.7867      1.078         86        640: 100%|██████████| 103/103 [00:12<00:00,  8.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.07it/s]
#                    all        169       1397      0.737      0.655      0.703      0.442
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/225       2.2G      1.069     0.7777      1.074        138        640: 100%|██████████| 103/103 [00:12<00:00,  8.26it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.06it/s]
#                    all        169       1397      0.782      0.646      0.721      0.443
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/225      2.27G      1.055     0.7799      1.072        154        640: 100%|██████████| 103/103 [00:12<00:00,  8.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.99it/s]
#                    all        169       1397      0.724      0.683      0.726      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/225      2.25G      1.062     0.7816      1.077        117        640: 100%|██████████| 103/103 [00:12<00:00,  8.28it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.99it/s]
#                    all        169       1397      0.746      0.648      0.692      0.419
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/225      2.25G      1.056     0.7753      1.078        130        640: 100%|██████████| 103/103 [00:12<00:00,  8.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.00it/s]
#                    all        169       1397      0.766      0.637      0.715      0.444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/225      2.27G      1.049     0.7749      1.069         76        640: 100%|██████████| 103/103 [00:12<00:00,  8.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.04it/s]
#                    all        169       1397      0.702      0.674      0.714       0.44
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/225      2.27G      1.046     0.7624      1.063         90        640: 100%|██████████| 103/103 [00:12<00:00,  8.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.10it/s]
#                    all        169       1397       0.78      0.655      0.714       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/225      2.25G      1.053      0.766      1.072         89        640: 100%|██████████| 103/103 [00:12<00:00,  8.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.11it/s]
#                    all        169       1397      0.785      0.643      0.716      0.452
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/225      2.24G      1.028     0.7592      1.063        107        640: 100%|██████████| 103/103 [00:12<00:00,  8.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.11it/s]
#                    all        169       1397      0.744       0.64      0.702       0.43
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/225      2.24G      1.041     0.7599      1.064        115        640: 100%|██████████| 103/103 [00:12<00:00,  8.28it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.01it/s]
#                    all        169       1397      0.766      0.669      0.741       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/225      2.24G      1.025     0.7464      1.063        108        640: 100%|██████████| 103/103 [00:12<00:00,  8.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.06it/s]
#                    all        169       1397      0.813      0.649       0.73      0.453
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/225      2.33G      1.029     0.7521      1.061        123        640: 100%|██████████| 103/103 [00:12<00:00,  8.16it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.05it/s]
#                    all        169       1397      0.769      0.656      0.711      0.441
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/225      2.23G      1.018     0.7393      1.064         94        640: 100%|██████████| 103/103 [00:12<00:00,  8.23it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.13it/s]
#                    all        169       1397      0.771      0.667      0.722       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/225      2.25G      1.026     0.7445      1.055        150        640: 100%|██████████| 103/103 [00:12<00:00,  8.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.91it/s]
#                    all        169       1397      0.723      0.655      0.701       0.43
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/225      2.26G      1.046     0.7465      1.064        129        640: 100%|██████████| 103/103 [00:12<00:00,  8.21it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.99it/s]
#                    all        169       1397      0.727      0.698      0.727      0.449
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/225       2.3G      1.012     0.7323      1.049        111        640: 100%|██████████| 103/103 [00:12<00:00,  8.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.11it/s]
#                    all        169       1397      0.733      0.694       0.73      0.449
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/225      2.33G      1.001     0.7199      1.044         79        640: 100%|██████████| 103/103 [00:12<00:00,  8.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.09it/s]
#                    all        169       1397      0.775      0.662      0.729      0.457
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/225      2.24G     0.9928     0.7189      1.048         97        640: 100%|██████████| 103/103 [00:12<00:00,  8.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.03it/s]
#                    all        169       1397      0.742      0.656      0.716      0.443
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/225      2.25G      1.006     0.7203      1.052         80        640: 100%|██████████| 103/103 [00:12<00:00,  8.30it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.15it/s]
#                    all        169       1397      0.787      0.676      0.734      0.459
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/225      2.26G     0.9917     0.7137      1.044         95        640: 100%|██████████| 103/103 [00:12<00:00,  8.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.99it/s]
#                    all        169       1397      0.775      0.672      0.737      0.466
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/225      2.24G     0.9925     0.7097      1.044        132        640: 100%|██████████| 103/103 [00:12<00:00,  8.26it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.11it/s]
#                    all        169       1397      0.732      0.702       0.72      0.454
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/225      2.27G     0.9792     0.6968      1.037        116        640: 100%|██████████| 103/103 [00:12<00:00,  8.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.06it/s]
#                    all        169       1397       0.76      0.642      0.722      0.447
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/225      2.33G     0.9867     0.7064      1.044        100        640: 100%|██████████| 103/103 [00:12<00:00,  8.21it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.06it/s]
#                    all        169       1397      0.741      0.684      0.716      0.443
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/225      2.37G     0.9993     0.7092      1.047         77        640: 100%|██████████| 103/103 [00:12<00:00,  8.21it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.16it/s]
#                    all        169       1397      0.756      0.663      0.728      0.454
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/225      2.25G     0.9795     0.6917      1.038        100        640: 100%|██████████| 103/103 [00:12<00:00,  8.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.00it/s]
#                    all        169       1397       0.75      0.672       0.71      0.446
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/225      2.34G     0.9711     0.6977      1.033        117        640: 100%|██████████| 103/103 [00:12<00:00,  8.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.16it/s]
#                    all        169       1397      0.753      0.665      0.732      0.449
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/225      2.37G     0.9717     0.6904      1.031        116        640: 100%|██████████| 103/103 [00:12<00:00,  8.17it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.11it/s]
#                    all        169       1397      0.724      0.718      0.743      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/225      2.35G     0.9678     0.6881      1.029         96        640: 100%|██████████| 103/103 [00:12<00:00,  8.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.30it/s]
#                    all        169       1397      0.732      0.692      0.717      0.452
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/225      2.37G     0.9601     0.6805      1.029        130        640: 100%|██████████| 103/103 [00:12<00:00,  8.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.27it/s]
#                    all        169       1397      0.738      0.688       0.72      0.449
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/225      2.26G     0.9592     0.6747      1.029         93        640: 100%|██████████| 103/103 [00:11<00:00,  8.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.18it/s]
#                    all        169       1397      0.737      0.689      0.709      0.449
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/225      2.35G      0.955     0.6748      1.029        152        640: 100%|██████████| 103/103 [00:12<00:00,  8.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.22it/s]
#                    all        169       1397      0.771      0.674      0.736      0.469
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/225      2.25G     0.9546     0.6748      1.029        129        640: 100%|██████████| 103/103 [00:12<00:00,  8.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.20it/s]
#                    all        169       1397      0.725      0.679      0.719      0.457
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/225      2.34G     0.9506     0.6681      1.028         69        640: 100%|██████████| 103/103 [00:12<00:00,  8.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.28it/s]
#                    all        169       1397      0.809      0.656      0.728      0.459
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/225      2.35G     0.9482     0.6696      1.022        129        640: 100%|██████████| 103/103 [00:11<00:00,  8.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.31it/s]
#                    all        169       1397      0.798      0.675      0.744      0.472
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/225      2.31G     0.9449     0.6648       1.02        113        640: 100%|██████████| 103/103 [00:11<00:00,  8.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.15it/s]
#                    all        169       1397      0.719      0.695      0.738      0.463
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/225      2.27G      0.939     0.6628      1.022         88        640: 100%|██████████| 103/103 [00:12<00:00,  8.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.21it/s]
#                    all        169       1397      0.751      0.683      0.717      0.452
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/225      2.26G     0.9501     0.6729      1.023        153        640: 100%|██████████| 103/103 [00:12<00:00,  8.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.11it/s]
#                    all        169       1397      0.764       0.69      0.732      0.464
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/225      2.37G     0.9363     0.6556      1.013        106        640: 100%|██████████| 103/103 [00:12<00:00,  8.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.10it/s]
#                    all        169       1397      0.786      0.658       0.73      0.458
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/225      2.35G     0.9312     0.6483      1.014        121        640: 100%|██████████| 103/103 [00:12<00:00,  8.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.21it/s]
#                    all        169       1397      0.745      0.675      0.722      0.456
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/225      2.25G     0.9371     0.6515      1.018         59        640: 100%|██████████| 103/103 [00:12<00:00,  8.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.16it/s]
#                    all        169       1397       0.75      0.681      0.737      0.461
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/225      2.27G     0.9318     0.6511      1.019         78        640: 100%|██████████| 103/103 [00:11<00:00,  8.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.20it/s]
#                    all        169       1397       0.78      0.672      0.745      0.464
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/225       2.2G     0.9207     0.6444      1.013        115        640: 100%|██████████| 103/103 [00:11<00:00,  8.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.30it/s]
#                    all        169       1397      0.768      0.688      0.746       0.47
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/225      2.24G     0.9182     0.6477      1.013         71        640: 100%|██████████| 103/103 [00:12<00:00,  8.56it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.29it/s]
#                    all        169       1397       0.79      0.664      0.731      0.464
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/225      2.24G     0.9202     0.6425       1.01        152        640: 100%|██████████| 103/103 [00:11<00:00,  8.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.17it/s]
#                    all        169       1397        0.8       0.65      0.729       0.46
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/225      2.23G     0.9154     0.6403      1.011        108        640: 100%|██████████| 103/103 [00:12<00:00,  8.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.11it/s]
#                    all        169       1397      0.717      0.702      0.717      0.459
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/225      2.26G     0.9115     0.6334      1.004        112        640: 100%|██████████| 103/103 [00:11<00:00,  8.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.35it/s]
#                    all        169       1397      0.753      0.687      0.726      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/225      2.26G     0.9115     0.6372      1.009        107        640: 100%|██████████| 103/103 [00:12<00:00,  8.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.31it/s]
#                    all        169       1397      0.736      0.707      0.734      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/225      2.27G     0.9171     0.6422      1.009         93        640: 100%|██████████| 103/103 [00:12<00:00,  8.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.34it/s]
#                    all        169       1397      0.759      0.662      0.726       0.46
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/225      2.24G     0.9187     0.6386      1.007         98        640: 100%|██████████| 103/103 [00:11<00:00,  8.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.17it/s]
#                    all        169       1397      0.758      0.688      0.725      0.464
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/225      2.25G     0.9084     0.6299      1.006        152        640: 100%|██████████| 103/103 [00:12<00:00,  8.56it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.20it/s]
#                    all        169       1397      0.713      0.715      0.722       0.46
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/225      2.24G     0.8984     0.6234      1.002        136        640: 100%|██████████| 103/103 [00:12<00:00,  8.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.40it/s]
#                    all        169       1397      0.756      0.663       0.72      0.454
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/225      2.25G     0.9124     0.6319      1.006        166        640: 100%|██████████| 103/103 [00:11<00:00,  8.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.23it/s]
#                    all        169       1397      0.722      0.711      0.737      0.471
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/225      2.25G      0.894     0.6222          1        122        640: 100%|██████████| 103/103 [00:12<00:00,  8.56it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.20it/s]
#                    all        169       1397      0.748      0.687      0.735      0.469
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/225      2.25G     0.8905     0.6241     0.9991        117        640: 100%|██████████| 103/103 [00:11<00:00,  8.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.26it/s]
#                    all        169       1397      0.722       0.69      0.733       0.46
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/225      2.24G     0.8981     0.6223      1.003        111        640: 100%|██████████| 103/103 [00:12<00:00,  8.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.16it/s]
#                    all        169       1397      0.735      0.731      0.731      0.457
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/225      2.38G     0.8836      0.616     0.9969         88        640: 100%|██████████| 103/103 [00:12<00:00,  8.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.19it/s]
#                    all        169       1397      0.799      0.678       0.74      0.467
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/225      2.26G     0.8881     0.6115     0.9974         98        640: 100%|██████████| 103/103 [00:12<00:00,  8.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.31it/s]
#                    all        169       1397      0.707      0.732      0.745      0.471
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/225      2.27G     0.8909     0.6204      1.003        124        640: 100%|██████████| 103/103 [00:12<00:00,  8.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.19it/s]
#                    all        169       1397      0.784      0.681      0.739      0.462
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/225      2.25G     0.8756     0.6083     0.9889        101        640: 100%|██████████| 103/103 [00:11<00:00,  8.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.21it/s]
#                    all        169       1397      0.771      0.702      0.751      0.469
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/225      2.35G     0.8742     0.6057     0.9947        112        640: 100%|██████████| 103/103 [00:11<00:00,  8.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.22it/s]
#                    all        169       1397      0.711      0.744      0.732       0.47
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/225      2.25G     0.8793     0.6096      0.995         92        640: 100%|██████████| 103/103 [00:11<00:00,  8.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.19it/s]
#                    all        169       1397      0.765      0.677      0.735      0.466
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/225      2.27G     0.8747      0.605     0.9952        117        640: 100%|██████████| 103/103 [00:11<00:00,  8.61it/s]
# ...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.15it/s]
#                    all        169       1397      0.744      0.692      0.732      0.471
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     159/225      2.25G     0.7514     0.5119     0.9442        116        640: 100%|██████████| 103/103 [00:12<00:00,  8.09it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.23it/s]
#                    all        169       1397      0.748      0.708      0.738      0.479
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     160/225      2.35G       0.76     0.5183     0.9516         79        640: 100%|██████████| 103/103 [00:12<00:00,  8.16it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.10it/s]
#                    all        169       1397      0.731      0.726      0.736      0.466
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     161/225      2.34G     0.7486     0.5108      0.945        112        640: 100%|██████████| 103/103 [00:12<00:00,  8.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.14it/s]
#                    all        169       1397      0.779      0.668      0.725      0.466
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     162/225      2.26G     0.7533     0.5125     0.9454        107        640: 100%|██████████| 103/103 [00:12<00:00,  8.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.20it/s]
#                    all        169       1397      0.733      0.721      0.738      0.471
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     163/225      2.27G      0.738     0.5052     0.9429         94        640: 100%|██████████| 103/103 [00:12<00:00,  8.16it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.11it/s]
#                    all        169       1397      0.756      0.725      0.743      0.475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     164/225      2.35G     0.7443     0.5092     0.9433        141        640: 100%|██████████| 103/103 [00:12<00:00,  8.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.02it/s]
#                    all        169       1397      0.746      0.696      0.737      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     165/225      2.24G      0.741     0.5016     0.9401        111        640: 100%|██████████| 103/103 [00:12<00:00,  8.16it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.18it/s]
#                    all        169       1397      0.779      0.689      0.739      0.473
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     166/225      2.24G       0.75     0.5115     0.9451        122        640: 100%|██████████| 103/103 [00:12<00:00,  8.14it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.25it/s]
#                    all        169       1397      0.821      0.666      0.739      0.469
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     167/225      2.25G     0.7364     0.5019     0.9415         98        640: 100%|██████████| 103/103 [00:12<00:00,  8.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.04it/s]
#                    all        169       1397      0.767      0.674      0.727      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     168/225      2.27G     0.7412     0.5053     0.9436        107        640: 100%|██████████| 103/103 [00:12<00:00,  8.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.20it/s]
#                    all        169       1397       0.79      0.679      0.737       0.47
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     169/225      2.23G     0.7307     0.4995     0.9383         82        640: 100%|██████████| 103/103 [00:12<00:00,  8.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.05it/s]
#                    all        169       1397      0.722      0.738      0.734      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     170/225      2.34G     0.7285     0.4966     0.9385        122        640: 100%|██████████| 103/103 [00:12<00:00,  8.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.97it/s]
#                    all        169       1397       0.75       0.71      0.739      0.471
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     171/225      2.34G     0.7354     0.5041     0.9425        141        640: 100%|██████████| 103/103 [00:12<00:00,  8.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.05it/s]
#                    all        169       1397      0.768      0.689      0.736      0.472
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     172/225      2.25G      0.732      0.504     0.9425        113        640: 100%|██████████| 103/103 [00:12<00:00,  8.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.14it/s]
#                    all        169       1397      0.788      0.667      0.734      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     173/225      2.34G     0.7267     0.4952     0.9359        107        640: 100%|██████████| 103/103 [00:12<00:00,  8.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.16it/s]
#                    all        169       1397        0.7      0.739      0.738      0.476
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     174/225      2.27G     0.7302     0.4996     0.9377        114        640: 100%|██████████| 103/103 [00:12<00:00,  8.21it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.08it/s]
#                    all        169       1397       0.79      0.664      0.733      0.473
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     175/225      2.26G     0.7282     0.4945      0.938         87        640: 100%|██████████| 103/103 [00:12<00:00,  8.17it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.15it/s]
#                    all        169       1397      0.758      0.699      0.742      0.476
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     176/225      2.25G     0.7305     0.4998     0.9437         65        640: 100%|██████████| 103/103 [00:12<00:00,  8.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.07it/s]
#                    all        169       1397      0.755      0.712       0.74      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     177/225      2.26G     0.7307      0.499      0.941         64        640: 100%|██████████| 103/103 [00:12<00:00,  8.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.09it/s]
#                    all        169       1397      0.736      0.704      0.742      0.475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     178/225      2.34G     0.7203     0.4917      0.937         88        640: 100%|██████████| 103/103 [00:12<00:00,  8.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.04it/s]
#                    all        169       1397      0.792      0.657      0.734      0.475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     179/225      2.35G      0.722     0.4938      0.939        116        640: 100%|██████████| 103/103 [00:12<00:00,  8.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.04it/s]
#                    all        169       1397      0.723      0.729      0.737      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     180/225      2.25G      0.718     0.4874     0.9337        124        640: 100%|██████████| 103/103 [00:12<00:00,  8.16it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.19it/s]
#                    all        169       1397      0.743        0.7      0.732      0.472
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     181/225      2.25G     0.7108     0.4848      0.938         93        640: 100%|██████████| 103/103 [00:12<00:00,  8.21it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.05it/s]
#                    all        169       1397      0.782       0.67      0.736      0.479
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     182/225       2.2G     0.7177     0.4881     0.9333        116        640: 100%|██████████| 103/103 [00:12<00:00,  8.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.15it/s]
#                    all        169       1397      0.743      0.724      0.738      0.479
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     183/225      2.26G     0.7213     0.4881      0.934        114        640: 100%|██████████| 103/103 [00:12<00:00,  8.17it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.09it/s]
#                    all        169       1397      0.747      0.705      0.741      0.476
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     184/225      2.36G     0.7188      0.489      0.937        138        640: 100%|██████████| 103/103 [00:12<00:00,  8.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.03it/s]
#                    all        169       1397      0.735      0.715      0.736      0.477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     185/225      2.22G     0.7086     0.4815     0.9323         95        640: 100%|██████████| 103/103 [00:12<00:00,  8.16it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.03it/s]
#                    all        169       1397       0.74      0.708      0.742       0.48
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     186/225      2.24G     0.7129     0.4844     0.9353        133        640: 100%|██████████| 103/103 [00:12<00:00,  8.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.08it/s]
#                    all        169       1397      0.803      0.687      0.743      0.476
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     187/225      2.25G     0.7081     0.4841     0.9329        119        640: 100%|██████████| 103/103 [00:12<00:00,  8.21it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.13it/s]
#                    all        169       1397      0.757      0.713      0.743      0.479
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     188/225      2.25G     0.7164     0.4872     0.9345        105        640: 100%|██████████| 103/103 [00:12<00:00,  8.17it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.19it/s]
#                    all        169       1397      0.776      0.703      0.738      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     189/225      2.24G     0.7057     0.4838      0.933         89        640: 100%|██████████| 103/103 [00:12<00:00,  8.16it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.07it/s]
#                    all        169       1397       0.81      0.677      0.745       0.48
# Stopping training early as no improvement observed in last 50 epochs. Best results observed at epoch 139, best model saved as best.pt.
# To update EarlyStopping(patience=50) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 189 epochs completed in 0.727 hours.
# Optimizer stripped from runs\detect\train38\weights\last.pt, 6.3MB
# Optimizer stripped from runs\detect\train38\weights\best.pt, 6.3MB
#
# Validating runs\detect\train38\weights\best.pt...
# Ultralytics YOLOv8.0.196  Python-3.12.4 torch-2.5.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# Model summary (fused): 168 layers, 3006428 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:02<00:00,  2.64it/s]
#                    all        169       1397      0.735      0.704      0.738      0.483
#                   Ball        169        118      0.752      0.695       0.74       0.44
#                  Coach        169         81      0.561      0.444      0.457      0.275
#                 Player        169       1042      0.849      0.871      0.906      0.659
#                Referee        169        156      0.777      0.805      0.846      0.559
# Speed: 0.3ms preprocess, 1.5ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to runs\detect\train38
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1, 2, 3])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x000001A69416D280>
# fitness: 0.5088086614386143
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# maps: array([     0.4402,     0.27475,     0.65921,     0.55942])
# names: {0: 'Ball', 1: 'Coach', 2: 'Player', 3: 'Referee'}
# plot: True
# results_dict: {'metrics/precision(B)': 0.7347483754705272, 'metrics/recall(B)': 0.7039144688547473, 'metrics/mAP50(B)': 0.7375635186607321, 'metrics/mAP50-95(B)': 0.4833914550806012, 'fitness': 0.5088086614386143}
# save_dir: WindowsPath('runs/detect/train38')
# speed: {'preprocess': 0.3200042882614587, 'inference': 1.451533221634182, 'loss': 0.0059393030651927695, 'postprocess': 1.6842325763589532}
